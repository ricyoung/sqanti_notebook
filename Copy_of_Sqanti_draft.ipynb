# %% [markdown]
# <a href="https://colab.research.google.com/github/ricyoung/sqanti_notebook/blob/main/Copy_of_Sqanti_draft.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%bash
# MINICONDA_INSTALLER_SCRIPT=Miniconda2-latest-Linux-x86_64.sh
# MINICONDA_PREFIX=/usr/local
# wget https://repo.continuum.io/miniconda/$MINICONDA_INSTALLER_SCRIPT
# chmod +x $MINICONDA_INSTALLER_SCRIPT
# ./$MINICONDA_INSTALLER_SCRIPT -b -f -p $MINICONDA_PREFIX
# Out:
# PREFIX=/usr/local
# Unpacking payload ...
# ...
# Solving environment: ...working...
# The environment is inconsistent, please check the package plan carefully
# The following packages are causing the inconsistency:
#
#   - defaults/noarch::certifi==2020.6.20=pyhd3eb1b0_3
#   - defaults/noarch::pyopenssl==20.0.1=pyhd3eb1b0_1
#   - conda-forge/linux-64::liblapack==3.9.0=10_openblas
#   - conda-forge/linux-64::gcc_linux-64==9.3.0=hf25ea35_33
#   - defaults/linux-64::ruamel_yaml==0.15.87=py27h7b6447c_0
#   - defaults/linux-64::setuptools==44.0.0=py27_0
#   - defaults/noarch::requests==2.25.1=pyhd3eb1b0_0
#   - defaults/noarch::idna==2.10=pyhd3eb1b0_0
#   - defaults/linux-64::tk==8.6.10=hbc83047_0
#   - defaults/linux-64::urllib3==1.25.7=py27_0
#   - defaults/linux-64::libgcc-ng==9.3.0=h5101ec6_17
#   - defaults/linux-64::zlib==1.2.11=h7b6447c_3
#   - defaults/linux-64::cryptography==2.8=py27h1ba5d50_0
#   - defaults/linux-64::libstdcxx-ng==9.3.0=hd4cf53a_17
# ...

# %%
! conda update -n base -c defaults conda -y
! conda config --add channels defaults
! conda config --add channels bioconda
! conda config --add channels conda-forge
# Out:
# done
# \
# The environment is inconsistent, please check the package plan carefully
# The following packages are causing the inconsistency:
#
#   - defaults/linux-64::cffi==1.14.0=py27he30daa8_1
#   - defaults/noarch::ipaddress==1.0.23=py_0
#   - defaults/linux-64::tk==8.6.10=hbc83047_0
#   - defaults/linux-64::sqlite==3.36.0=hc218d9a_0
#   - defaults/noarch::idna==2.10=pyhd3eb1b0_0
#   - defaults/linux-64::readline==8.1=h27cfd23_0
#   - defaults/linux-64::chardet==3.0.4=py27_1003
#   - defaults/linux-64::ncurses==6.2=he6710b0_1
#   - defaults/linux-64::futures==3.3.0=py27_0
#   - conda-forge/linux-64::libblas==3.9.0=10_openblas
#   - conda-forge/linux-64::gcc_impl_linux-64==9.3.0=hda68d29_13
#   - defaults/noarch::pyopenssl==20.0.1=pyhd3eb1b0_1
#   - defaults/linux-64::libstdcxx-ng==9.3.0=hd4cf53a_17
#   - defaults/linux-64::yaml==0.1.7=had09818_2
#   - defaults/linux-64::openssl==1.1.1k=h27cfd23_0
#   - defaults/noarch::asn1crypto==1.4.0=py_0
# ...

# %%
# !conda --version
# Out:
# conda 4.8.3

# %%
# %%bash
# conda update conda --yes
# Out:
# ...
# Solving environment: ...working...
# The environment is inconsistent, please check the package plan carefully
# The following packages are causing the inconsistency:
#
#   - defaults/linux-64::cffi==1.14.0=py27he30daa8_1
#   - defaults/noarch::ipaddress==1.0.23=py_0
#   - defaults/linux-64::tk==8.6.10=hbc83047_0
#   - defaults/linux-64::sqlite==3.36.0=hc218d9a_0
#   - defaults/noarch::idna==2.10=pyhd3eb1b0_0
#   - defaults/linux-64::readline==8.1=h27cfd23_0
#   - defaults/linux-64::chardet==3.0.4=py27_1003
#   - defaults/linux-64::ncurses==6.2=he6710b0_1
#   - defaults/linux-64::futures==3.3.0=py27_0
#   - conda-forge/linux-64::libblas==3.9.0=10_openblas
#   - conda-forge/linux-64::gcc_impl_linux-64==9.3.0=hda68d29_13
#   - defaults/noarch::pyopenssl==20.0.1=pyhd3eb1b0_1
#   - defaults/linux-64::libstdcxx-ng==9.3.0=hd4cf53a_17
#   - defaults/linux-64::yaml==0.1.7=had09818_2
#   - defaults/linux-64::openssl==1.1.1k=h27cfd23_0
#   - defaults/noarch::asn1crypto==1.4.0=py_0
# ...

# %%
# !conda update -n base -c defaults conda --yes
# Out:
# done
# -
# The environment is inconsistent, please check the package plan carefully
# The following packages are causing the inconsistency:
#
#   - defaults/linux-64::cffi==1.14.0=py27he30daa8_1
#   - defaults/noarch::ipaddress==1.0.23=py_0
#   - defaults/linux-64::tk==8.6.10=hbc83047_0
#   - defaults/linux-64::sqlite==3.36.0=hc218d9a_0
#   - defaults/noarch::idna==2.10=pyhd3eb1b0_0
#   - defaults/linux-64::readline==8.1=h27cfd23_0
#   - defaults/linux-64::chardet==3.0.4=py27_1003
#   - defaults/linux-64::ncurses==6.2=he6710b0_1
#   - defaults/linux-64::futures==3.3.0=py27_0
#   - conda-forge/linux-64::libblas==3.9.0=10_openblas
#   - conda-forge/linux-64::gcc_impl_linux-64==9.3.0=hda68d29_13
#   - defaults/noarch::pyopenssl==20.0.1=pyhd3eb1b0_1
#   - defaults/linux-64::libstdcxx-ng==9.3.0=hd4cf53a_17
#   - defaults/linux-64::yaml==0.1.7=had09818_2
#   - defaults/linux-64::openssl==1.1.1k=h27cfd23_0
#   - defaults/noarch::asn1crypto==1.4.0=py_0
# ...

# %%
# !conda install anaconda --yes
# Out:
# done
# \
# The environment is inconsistent, please check the package plan carefully
# The following packages are causing the inconsistency:
#
#   - defaults/linux-64::cffi==1.14.0=py27he30daa8_1
#   - defaults/noarch::ipaddress==1.0.23=py_0
#   - defaults/linux-64::tk==8.6.10=hbc83047_0
#   - defaults/linux-64::sqlite==3.36.0=hc218d9a_0
#   - defaults/noarch::idna==2.10=pyhd3eb1b0_0
#   - defaults/linux-64::readline==8.1=h27cfd23_0
#   - defaults/linux-64::chardet==3.0.4=py27_1003
#   - defaults/linux-64::ncurses==6.2=he6710b0_1
#   - defaults/linux-64::futures==3.3.0=py27_0
#   - conda-forge/linux-64::libblas==3.9.0=10_openblas
#   - conda-forge/linux-64::gcc_impl_linux-64==9.3.0=hda68d29_13
#   - defaults/noarch::pyopenssl==20.0.1=pyhd3eb1b0_1
#   - defaults/linux-64::libstdcxx-ng==9.3.0=hd4cf53a_17
#   - defaults/linux-64::yaml==0.1.7=had09818_2
#   - defaults/linux-64::openssl==1.1.1k=h27cfd23_0
#   - defaults/noarch::asn1crypto==1.4.0=py_0
# ...

# %%
# !wget https://github.com/ConesaLab/SQANTI3/archive/refs/tags/v4.1.tar.gz

# %%
# !tar -xvf v4.1.tar.gz

# %%
# %cd ./SQANTI3-4.1
# !ls

# %%
# !pwd

# %%
# !conda env create -f SQANTI3.conda_env.yml

# %%
# !source activate SQANTI3.env

# %%
# !pwd

# %%
# !wget http://hgdownload.cse.ucsc.edu/admin/exe/linux.x86_64/gtfToGenePred -P /content/SQANTI3-4.1/SQANTI3/utilities/
# !chmod +x /content/SQANTI3-4.1/SQANTI3/utilities/gtfToGenePred

# %%
# !git clone https://github.com/Magdoll/cDNA_Cupcake.git

# %%
# %cd cDNA_Cupcake

# %%
# !conda install -c anaconda cython --yes

# %%
# !conda install -c anaconda numpy --yes

# %%
# !sudo apt-get install python3-dev
# !sudo apt-get install libevent-dev
# !sudo apt install build-essential

# %%
# !conda install -c conda-forge gcc_linux-64 -y

# %%
# !conda install -c bioconda bx-python -y

# %%
import numpy

# %%
# !python setup.py build

# %%
# !python setup.py install

# %%
print(numpy.__version__)
